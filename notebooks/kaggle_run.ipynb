# %% [markdown]
# # Electricity demand LSTM (Kaggle)
#
# 1. Add the dataset **smart-city-energy-dataset** as a notebook input.
# 2. Replace the clone URL with your GitHub repo if needed.
# 3. Run all cells (GPU recommended).

# %%
import os
import sys

REPO_URL = "https://github.com/mehmetertac/EDP_LSTM.git"
WORKING = "/kaggle/working/EDP_LSTM"

if not os.path.isdir(WORKING):
    # !git clone {REPO_URL} {WORKING}

if WORKING not in sys.path:
    sys.path.insert(0, WORKING)

os.chdir(WORKING)
print("Using repo:", WORKING)

# %%
from src.train import main

main()
